# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
utils = pd.read_csv('utilities.csv')

# %%
utils.head(2)
# Out:
#     Company  Fixed_charge   RoR  Cost  Load  D Demand  Sales  Nuclear  \
# 0  Arizona           1.06   9.2   151  54.4       1.6   9077      0.0
# 1   Boston           0.89  10.3   202  57.9       2.2   5088     25.3
#
#    Fuel_Cost
# 0      0.628
# 1      1.555

# %%
ax = utils.plot.scatter(x='Sales', y='Fuel_Cost', figsize=(6,6))
points = utils[['Sales', 'Fuel_Cost','Company']]
_ = points.apply(lambda x: ax.text(*x, rotation=20, horizontalalignment='left', verticalalignment='bottom', fontsize=8), axis=1)
